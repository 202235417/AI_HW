# %% [markdown]
# # iris 데이터셋 시각화

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from pandas import Series, DataFrame

# %%
iris = load_iris()

iris.keys()

iris_data=iris.data
iris_target=iris.target
print(iris['feature_names']) #데이터 프레임을 만들때 얘네 이름을 넣기 위해서
print(iris['target_names'])

df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
iris = sns.load_dataset("iris")

print(iris.shape)
iris.head()
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
#결측치
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#1. Pclass 레이블별 갯수 및 차트표시
sns.countplot(x='species', data=iris)
plt.xlabel('species', color='red')
plt.ylabel('count')
plt.title('species')
# Out:
# Text(0.5, 1.0, 'species')

# %%
# 박스플롯
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# 페어플롯 : 피처끼리의 상관관계 확인
sns.pairplot(iris, hue="species", size=3, diag_kind='hist')
# Out:
# C:\Users\wldnj\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 데이터 나누기

# %%
#훈련세트, 테스트세트 나누기
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_target, test_size=0.2,  random_state=7)

print('X_train 개수: ', len(X_train),', X_test 개수: ', len(X_test))
# Out:
# X_train 개수:  120 , X_test 개수:  30

# %% [markdown]
# 데이터 set 확인하기

# %%
X_train.shape, y_train.shape
# Out:
# ((120, 4), (120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((30, 4), (30,))

# %%
y_train, y_test
# Out:
# (array([2, 1, 0, 2, 1, 0, 0, 0, 0, 2, 2, 1, 2, 2, 1, 0, 1, 1, 2, 0, 0, 0,
#         2, 0, 2, 1, 1, 1, 0, 0, 0, 1, 2, 1, 1, 0, 2, 0, 0, 2, 2, 0, 2, 0,
#         1, 2, 1, 0, 1, 0, 2, 2, 1, 0, 0, 1, 2, 0, 2, 2, 1, 0, 1, 0, 2, 2,
#         0, 0, 2, 1, 2, 2, 1, 0, 0, 2, 0, 0, 1, 2, 2, 1, 1, 0, 2, 0, 0, 1,
#         1, 2, 0, 1, 1, 2, 2, 1, 2, 0, 1, 1, 0, 0, 0, 1, 1, 0, 2, 2, 1, 2,
#         0, 2, 1, 1, 0, 2, 1, 2, 1, 0]),
#  array([2, 1, 0, 1, 2, 0, 1, 1, 0, 1, 1, 1, 0, 2, 0, 1, 2, 2, 0, 0, 1, 2,
#         1, 2, 2, 2, 1, 1, 2, 2]))

# %% [markdown]
# # 데이터 분류
